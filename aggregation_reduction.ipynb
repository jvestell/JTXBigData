# %%
from pymongo import MongoClient

# Initialize MongoDB Connection
client = MongoClient('mongodb+srv://JTXBigData:pJRAyKW9QnqE7B1G@jtxbigdatacluster.dzo50pn.mongodb.net/')
db = client['JTXBigDataCluster']
collection = db['jtx-reduced-data']

# Query 1: Calculate the average "MA_X-4" for each hour of the day
pipeline = [
    {
        '$group': {
            '_id': {'hourOfDay': '$hourOfDay'},
            'avg_MA_X-4': {'$avg': '$MA_X-4'}
        }
    }
]

result1 = list(collection.aggregate(pipeline))

# Query 2: Calculate the total "holiday" values for each day
pipeline = [
    {
        '$group': {
            '_id': {'date': '$datetime'},
            'total_holiday': {'$sum': '$holiday'}
        }
    }
]

result2 = list(collection.aggregate(pipeline))

# Query 3: Find the maximum "T2M_toc" value and the corresponding timestamp
pipeline = [
    {
        '$sort': {'T2M_toc': -1}
    },
    {
        '$limit': 1
    }
]

result3 = list(collection.aggregate(pipeline))

# Query 4: Calculate the standard deviation of "dayOfWeek" for the entire dataset
pipeline = [
    {
        '$group': {
            '_id': None,
            'stddev_dayOfWeek': {'$stdDevSamp': '$dayOfWeek'}
        }
    }
]

result4 = list(collection.aggregate(pipeline))

# Query 5: Calculate the total "MA_X-4" for each month and year
pipeline = [
    {
        '$group': {
            '_id': {
                'year': {'$year': '$datetime'},
                'month': {'$month': '$datetime'}
            },
            'total_MA_X-4': {'$sum': '$MA_X-4'}
        }
    }
]

result5 = list(collection.aggregate(pipeline))

# Print the results
print("Query 1: Average 'MA_X-4' for each hour of the day")
for item in result1:
    print(item)

print("\nQuery 2: Total 'holiday' values for each day")
for item in result2:
    print(item)

print("\nQuery 3: Maximum 'T2M_toc' value and timestamp")
for item in result3:
    print(item)

print("\nQuery 4: Standard Deviation of 'dayOfWeek'")
for item in result4:
    print(item)

print("\nQuery 5: Total 'MA_X-4' for each month and year")
for item in result5:
    print(item)
